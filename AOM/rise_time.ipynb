# %%
import pandas as pd
import numpy as np
import fit_funcs as ff
import matplotlib.pyplot as mp

path = r"C:\Users\keena\Desktop\995RIS01.CSV"

# %%
data = pd.read_csv(path)
time = data['in s'][1400:]
marker = data['C1 in V'][1400:]
signal = data['C2 in V'][1400:]

fig, ax = mp.subplots()
ax.plot(time, signal)

# %%
fit, err = ff.fit_rise_time(time, signal)
fit
# Out:
# array([ 5.18787225e-01, -9.31508687e-06,  2.20382739e-07])

# %%
fit[1] * 1E9, fit[-1] * 1E9
# Out:
# (-9315.086872518608, 220.38273919908085)

# %%
fig, ax = mp.subplots()
ax.plot(time, signal)
ax.plot(time, ff.rise_time(time, *fit))
